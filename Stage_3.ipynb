# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Extracting features of 2018 - 2020 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2018"
df1 = pd.read_html(link,header=0)

# %%
df1[5]
# Out:
#      Opening  Opening.1                       Title  \
# 0    OCTOBER          2            Power of the Air
# 1    OCTOBER          5                       Venom
# 2    OCTOBER          5              A Star Is Born
# 3    OCTOBER          5             The Hate U Give
# 4    OCTOBER         10            The Happy Prince
# ..       ...        ...                         ...
# 60  DECEMBER         25             Holmes & Watson
# 61  DECEMBER         25                        Vice
# 62  DECEMBER         25         On the Basis of Sex
# 63  DECEMBER         25                   Destroyer
# 64  DECEMBER         28  Black Mirror: Bandersnatch
#
#                               Production company  \
# 0                            Five & Two Pictures
# 1       Columbia Pictures / Marvel Entertainment
# 2                          Warner Bros. Pictures
# 3           20th Century Fox / Fox 2000 Pictures
# 4                         Sony Pictures Classics
# ...

# %%
df1 = pd.read_html(link,header=0)[2]
df2 = pd.read_html(link,header=0)[3]
df3 = pd.read_html(link,header=0)[4]
df4 = pd.read_html(link,header=0)[5]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#       Opening  Opening.1                       Title  \
# 0     JANUARY          5     Insidious: The Last Key
# 1     JANUARY          5            The Strange Ones
# 2     JANUARY          5                    Stratton
# 3     JANUARY         10               Sweet Country
# 4     JANUARY         12                The Commuter
# ..        ...        ...                         ...
# 263  DECEMBER         25             Holmes & Watson
# 264  DECEMBER         25                        Vice
# 265  DECEMBER         25         On the Basis of Sex
# 266  DECEMBER         25                   Destroyer
# 267  DECEMBER         28  Black Mirror: Bandersnatch
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2                                    Momentum Pictures
# 3                                 Samuel Goldwyn Films
# ...

# %%
# install the tmdb library
pip install tmdb
# Out:
# ...
#   Created wheel for tmdb: filename=tmdb-0.0.0-py3-none-any.whl size=3656 sha256=4abba77910d4173f7df5c760d7145f70d06941f1bc436ffd3aac165c73e82020
#   Stored in directory: c:\users\amd\appdata\local\pip\cache\wheels\a4\ec\4b\947442397538ea66b9bb3eaff8606771b3f592382d7037eb24
# Successfully built tmdb
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# install the tmdb v3 api library
pip install tmdbv3api
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = ''

# %%
from tmdbv3api import Movie
tmdb_movie = Movie()

# %%
tmdb_movie.search('Destroyer')[1].id
# Out:
# 471507

# %%
requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(471507,tmdb.api_key)).json()
# Out:
# {'adult': False,
#  'backdrop_path': '/b9tR4BKmHRgYBLEr4UhlKQD4z29.jpg',
#  'belongs_to_collection': None,
#  'budget': 9000000,
#  'genres': [{'id': 53, 'name': 'Thriller'},
#   {'id': 80, 'name': 'Crime'},
#   {'id': 18, 'name': 'Drama'},
#   {'id': 28, 'name': 'Action'}],
#  'homepage': 'http://www.destroyer.movie',
#  'id': 471507,
#  'imdb_id': 'tt7137380',
#  'original_language': 'en',
#  'original_title': 'Destroyer',
#  'overview': 'Erin Bell is an LAPD detective who, as a young cop, was placed undercover with a gang in the California desert with tragic results. When the leader of that gang re-emerges many years later, she must work her way back through the remaining members and into her own history with them to finally reckon with the demons that destroyed her past.',
#  'popularity': 13.012,
#  'poster_path': '/sHw9gTdo43nJL82py0oaROkXXNr.jpg',
#  'production_companies': [{'id': 104363,
#    'logo_path': '/jnmqDxwCVAbKJkne5TDSkhj7mzo.png',
#    'name': '30WEST',
# ...

# %%
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    movie_id = result[0].id
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
    data_json = response.json()
    if data_json['genres']:
        genre_str = " " 
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name'])
        return genre_str.join(genres)
    else:
        np.NaN

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))
df
# Out:
#       Opening  Opening.1                       Title  \
# 0     JANUARY          5     Insidious: The Last Key
# 1     JANUARY          5            The Strange Ones
# 2     JANUARY          5                    Stratton
# 3     JANUARY         10               Sweet Country
# 4     JANUARY         12                The Commuter
# ..        ...        ...                         ...
# 263  DECEMBER         25             Holmes & Watson
# 264  DECEMBER         25                        Vice
# 265  DECEMBER         25         On the Basis of Sex
# 266  DECEMBER         25                   Destroyer
# 267  DECEMBER         28  Black Mirror: Bandersnatch
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2                                    Momentum Pictures
# 3                                 Samuel Goldwyn Films
# ...

# %%
df_2018 = df[['Title','Cast and crew','genres']]
df_2018
# Out:
#                           Title  \
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 263             Holmes & Watson
# 264                        Vice
# 265         On the Basis of Sex
# 266                   Destroyer
# 267  Black Mirror: Bandersnatch
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 263  Etan Cohen (director/screenplay); Will Ferrell...
# 264  Adam McKay (director/screenplay); Christian Ba...
# 265  Mimi Leder (director); Daniel Stiepleman (scre...
# ...

# %%
def get_Director(x):
    if ' (director)' in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df['director_name'] = df['Cast and crew'].map(lambda x: get_Director(str(x)))
df
# Out:
#       Opening  Opening.1                       Title  \
# 0     JANUARY          5     Insidious: The Last Key
# 1     JANUARY          5            The Strange Ones
# 2     JANUARY          5                    Stratton
# 3     JANUARY         10               Sweet Country
# 4     JANUARY         12                The Commuter
# ..        ...        ...                         ...
# 263  DECEMBER         25             Holmes & Watson
# 264  DECEMBER         25                        Vice
# 265  DECEMBER         25         On the Basis of Sex
# 266  DECEMBER         25                   Destroyer
# 267  DECEMBER         28  Black Mirror: Bandersnatch
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2                                    Momentum Pictures
# 3                                 Samuel Goldwyn Films
# ...

# %%
df_2018['director_name'] = df['director_name']

# %%
df.drop('director_name',axis=1)
# Out:
#       Opening  Opening.1                       Title  \
# 0     JANUARY          5     Insidious: The Last Key
# 1     JANUARY          5            The Strange Ones
# 2     JANUARY          5                    Stratton
# 3     JANUARY         10               Sweet Country
# 4     JANUARY         12                The Commuter
# ..        ...        ...                         ...
# 263  DECEMBER         25             Holmes & Watson
# 264  DECEMBER         25                        Vice
# 265  DECEMBER         25         On the Basis of Sex
# 266  DECEMBER         25                   Destroyer
# 267  DECEMBER         28  Black Mirror: Bandersnatch
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2                                    Momentum Pictures
# 3                                 Samuel Goldwyn Films
# ...

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# <ipython-input-64-94b1a1569c5d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# <ipython-input-66-75f2be6b779a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2018['actor_3_name'] = df_2018['Cast and crew'].map(lambda x: get_actor3(x))
# Out:
# <ipython-input-69-c6969dc4d5e1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_3_name'] = df_2018['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2018
# Out:
#                           Title  \
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 263             Holmes & Watson
# 264                        Vice
# 265         On the Basis of Sex
# 266                   Destroyer
# 267  Black Mirror: Bandersnatch
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 263  Etan Cohen (director/screenplay); Will Ferrell...
# 264  Adam McKay (director/screenplay); Christian Ba...
# 265  Mimi Leder (director); Daniel Stiepleman (scre...
# ...

# %%
df_2018 = df_2018.rename(columns={'Title':'movie_title'})

# %%
new_df18 = df_2018

# %%
new_df18 = new_df18[['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]
new_df18
# Out:
#           director_name     actor_1_name            actor_2_name  \
# 0          Adam Robitel        Lin Shaye           Angus Sampson
# 1      Lauren Wolkstein    Alex Pettyfer  James Freedson-Jackson
# 2            Simon West   Dominic Cooper          Austin Stowell
# 3      Warwick Thornton      Bryan Brown               Sam Neill
# 4    Jaume Collet-Serra      Liam Neeson            Vera Farmiga
# ..                  ...              ...                     ...
# 263          Etan Cohen     Will Ferrell          John C. Reilly
# 264          Adam McKay   Christian Bale               Amy Adams
# 265          Mimi Leder   Felicity Jones            Armie Hammer
# 266        Karyn Kusama    Nicole Kidman          Sebastian Stan
# 267         David Slade  Fionn Whitehead            Will Poulter
#
#        actor_3_name                                           genres  \
# 0    Leigh Whannell                          Horror Mystery Thriller
# ...

# %%
new_df18['actor_2_name'] = new_df18['actor_2_name'].replace(np.nan, 'unknown')
new_df18['actor_3_name'] = new_df18['actor_3_name'].replace(np.nan, 'unknown')
# Out:
# <ipython-input-85-5fc5b8828a08>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df18['actor_2_name'] = new_df18['actor_2_name'].replace(np.nan, 'unknown')
# <ipython-input-85-5fc5b8828a08>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df18['actor_3_name'] = new_df18['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df18['movie_title'] = new_df18['movie_title'].str.lower()
# Out:
# <ipython-input-86-7ff1db2452f2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df18['movie_title'] = new_df18['movie_title'].str.lower()

# %%
new_df18['comb'] = new_df18['actor_1_name'] + ' ' + new_df18['actor_2_name'] + ' '+ new_df18['actor_3_name'] + ' '+ new_df18['director_name'] +' ' + new_df18['genres']

# %%
new_df18
# Out:
#           director_name     actor_1_name            actor_2_name  \
# 0          Adam Robitel        Lin Shaye           Angus Sampson
# 1      Lauren Wolkstein    Alex Pettyfer  James Freedson-Jackson
# 2            Simon West   Dominic Cooper          Austin Stowell
# 3      Warwick Thornton      Bryan Brown               Sam Neill
# 4    Jaume Collet-Serra      Liam Neeson            Vera Farmiga
# ..                  ...              ...                     ...
# 263          Etan Cohen     Will Ferrell          John C. Reilly
# 264          Adam McKay   Christian Bale               Amy Adams
# 265          Mimi Leder   Felicity Jones            Armie Hammer
# 266        Karyn Kusama    Nicole Kidman          Sebastian Stan
# 267         David Slade  Fionn Whitehead            Will Poulter
#
#        actor_3_name                                           genres  \
# 0    Leigh Whannell                          Horror Mystery Thriller
# ...

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2019"
df1 = pd.read_html(link, header=0)[3]
df2 = pd.read_html(link, header=0)[4]
df3 = pd.read_html(link, header=0)[5]
df4 = pd.read_html(link, header=0)[6]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
df
# Out:
#       Opening  Opening.1             Title  \
# 0     JANUARY          4       Escape Room
# 1     JANUARY          4        Rust Creek
# 2     JANUARY          4  American Hangman
# 3     JANUARY         11  A Dog's Way Home
# 4     JANUARY         11        The Upside
# ..        ...        ...               ...
# 238  DECEMBER         25      Little Women
# 239  DECEMBER         25              1917
# 240  DECEMBER         25        Just Mercy
# 241  DECEMBER         27          Clemency
# 242  DECEMBER         27        Apparition
#
#                                     Production company  \
# 0                                    Columbia Pictures
# 1                                            IFC Films
# 2                          Hangman Justice Productions
# 3                                    Columbia Pictures
# 4                                    STX Entertainment
# ..                                                 ...
# ...

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2019 = df[['Title','Cast and crew','genres']]

# %%
df_2019
# Out:
#                 Title                                      Cast and crew  \
# 0         Escape Room  Adam Robitel (director); Bragi F. Schut, Maria...
# 1          Rust Creek  Jen McGowan (director); Julie Lipson (screenpl...
# 2    American Hangman  Wilson Coneybeare (director/screenplay); Donal...
# 3    A Dog's Way Home  Charles Martin Smith (director); W. Bruce Came...
# 4          The Upside  Neil Burger (director); Jon Hartmere (screenpl...
# ..                ...                                                ...
# 238      Little Women  Greta Gerwig (director/screenplay); Saoirse Ro...
# 239              1917  Sam Mendes (director/screenplay); Krysty Wilso...
# 240        Just Mercy  Destin Daniel Cretton (director/screenplay), A...
# 241          Clemency  Chinonye Chukwu (director/screenplay); Alfre W...
# 242        Apparition  Waymon Boone (director/screenplay); Mena Suvar...
#
#                                        genres
# ...

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# <ipython-input-95-a433a4faa834>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# <ipython-input-97-eee71c5586b8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# <ipython-input-99-48d0aadc78c0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2019['actor_3_name'] = df_2019['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2019 = df_2019.rename(columns={'Title':'movie_title'})

# %%
new_df19 = df_2019.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df19['actor_2_name'] = new_df19['actor_2_name'].replace(np.nan, 'unknown')
new_df19['actor_3_name'] = new_df19['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df19['movie_title'] = new_df19['movie_title'].str.lower()

# %%
new_df19['comb'] = new_df19['actor_1_name'] + ' ' + new_df19['actor_2_name'] + ' '+ new_df19['actor_3_name'] + ' '+ new_df19['director_name'] +' ' + new_df19['genres']

# %%
new_df19
# Out:
#              director_name         actor_1_name          actor_2_name  \
# 0             Adam Robitel       Taylor Russell          Logan Miller
# 1              Jen McGowan    Hermione Corfield           Jay Paulson
# 2        Wilson Coneybeare    Donald Sutherland    Vincent Kartheiser
# 3     Charles Martin Smith  Bryce Dallas Howard    Edward James Olmos
# 4              Neil Burger       Bryan Cranston            Kevin Hart
# ..                     ...                  ...                   ...
# 238           Greta Gerwig        Saoirse Ronan           Emma Watson
# 239             Sam Mendes        George MacKay  Dean-Charles Chapman
# 240  Destin Daniel Cretton    Michael B. Jordan            Jamie Foxx
# 241        Chinonye Chukwu        Alfre Woodard        Wendell Pierce
# 242           Waymon Boone          Mena Suvari          Kevin Pollak
#
#          actor_3_name                                    genres  \
# ...

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2020"
df1 = pd.read_html(link, header=0)[3]
df2 = pd.read_html(link, header=0)[4]
df3 = pd.read_html(link, header=0)[5]
df4 = pd.read_html(link, header=0)[6]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
df
# Out:
#       Opening  Opening.1                  Title  \
# 0     JANUARY          3             The Grudge
# 1     JANUARY         10             Underwater
# 2     JANUARY         10            Like a Boss
# 3     JANUARY         10          Three Christs
# 4     JANUARY         10      Inherit the Viper
# ..        ...        ...                    ...
# 264  DECEMBER         25       We Can Be Heroes
# 265  DECEMBER         25      News of the World
# 266  DECEMBER         25  Promising Young Woman
# 267  DECEMBER         25     One Night in Miami
# 268  DECEMBER         30      Pieces of a Woman
#
#                                     Production company  \
# 0    Screen Gems / Stage 6 Films / Ghost House Pict...
# 1    20th Century Fox / TSG Entertainment / Chernin...
# 2                                   Paramount Pictures
# 3                                            IFC Films
# 4       Barry Films / Tycor International Film Company
# ...

# %%
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    if not result:
      return np.NaN
    else:
      movie_id = result[0].id
      response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
      data_json = response.json()
      if data_json['genres']:
          genre_str = " " 
          for i in range(0,len(data_json['genres'])):
              genres.append(data_json['genres'][i]['name'])
          return genre_str.join(genres)
      else:
          return np.NaN

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2020 = df[['Title','Cast and crew','genres']]
df_2020
# Out:
#                      Title                                      Cast and crew  \
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 264       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 265      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 266  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 267     One Night in Miami  Regina King (director); Kemp Powers (screenpla...
# 268      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
# ...

# %%
df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# <ipython-input-115-bc52fe9b0c35>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# <ipython-input-116-da3b02104b70>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(x))

# %%
df_2020['actor_2_name'] = df_2020['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# <ipython-input-117-4182ad640e21>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['actor_2_name'] = df_2020['Cast and crew'].map(lambda x: get_actor2(x))

# %%
df_2020['actor_3_name'] = df_2020['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2020 = df_2020.rename(columns={'Title':'movie_title'})
df_2020
# Out:
#                movie_title                                      Cast and crew  \
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 264       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 265      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 266  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 267     One Night in Miami  Regina King (director); Kemp Powers (screenpla...
# 268      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
# ...

# %%
new_df20 = df_2020[['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]
new_df20
# Out:
#         director_name           actor_1_name       actor_2_name  \
# 0       Nicolas Pesce     Andrea Riseborough      Demián Bichir
# 1      William Eubank        Kristen Stewart     Vincent Cassel
# 2       Miguel Arteta        Tiffany Haddish         Rose Byrne
# 3           Jon Avnet           Richard Gere     Peter Dinklage
# 4      Anthony Jerjen          Josh Hartnett  Margarita Levieva
# ..                ...                    ...                ...
# 264  Robert Rodriguez  Priyanka Chopra Jonas       Pedro Pascal
# 265   Paul Greengrass              Tom Hanks      Helena Zengel
# 266   Emerald Fennell         Carey Mulligan         Bo Burnham
# 267       Regina King      Kingsley Ben-Adir          Eli Goree
# 268  Kornél Mundruczó          Vanessa Kirby       Shia LaBeouf
#
#         actor_3_name                                  genres  \
# 0           John Cho                 Horror Mystery Thriller
# 1    Jessica Henwick  Action Horror Science Fiction Thriller
# ...

# %%
new_df20['comb'] = new_df20['actor_1_name'] + ' ' + new_df20['actor_2_name'] + ' '+ new_df20['actor_3_name'] + ' '+ new_df20['director_name'] +' ' + new_df20['genres']
new_df20
# Out:
#         director_name           actor_1_name       actor_2_name  \
# 0       Nicolas Pesce     Andrea Riseborough      Demián Bichir
# 1      William Eubank        Kristen Stewart     Vincent Cassel
# 2       Miguel Arteta        Tiffany Haddish         Rose Byrne
# 3           Jon Avnet           Richard Gere     Peter Dinklage
# 4      Anthony Jerjen          Josh Hartnett  Margarita Levieva
# ..                ...                    ...                ...
# 264  Robert Rodriguez  Priyanka Chopra Jonas       Pedro Pascal
# 265   Paul Greengrass              Tom Hanks      Helena Zengel
# 266   Emerald Fennell         Carey Mulligan         Bo Burnham
# 267       Regina King      Kingsley Ben-Adir          Eli Goree
# 268  Kornél Mundruczó          Vanessa Kirby       Shia LaBeouf
#
#         actor_3_name                                  genres  \
# 0           John Cho                 Horror Mystery Thriller
# 1    Jessica Henwick  Action Horror Science Fiction Thriller
# ...

# %%
my_df = new_df18.append(new_df19.append(new_df20,ignore_index=True),ignore_index=True)
my_df
# Out:
#           director_name           actor_1_name            actor_2_name  \
# 0          Adam Robitel              Lin Shaye           Angus Sampson
# 1      Lauren Wolkstein          Alex Pettyfer  James Freedson-Jackson
# 2            Simon West         Dominic Cooper          Austin Stowell
# 3      Warwick Thornton            Bryan Brown               Sam Neill
# 4    Jaume Collet-Serra            Liam Neeson            Vera Farmiga
# ..                  ...                    ...                     ...
# 775    Robert Rodriguez  Priyanka Chopra Jonas            Pedro Pascal
# 776     Paul Greengrass              Tom Hanks           Helena Zengel
# 777     Emerald Fennell         Carey Mulligan              Bo Burnham
# 778         Regina King      Kingsley Ben-Adir               Eli Goree
# 779    Kornél Mundruczó          Vanessa Kirby            Shia LaBeouf
#
#        actor_3_name                   genres              movie_title  \
# ...

# %%
old_df = pd.read_csv('new_data.csv')

# %%
old_df
# Out:
#               director_name          actor_1_name            actor_2_name  \
# 0             James Cameron           CCH Pounder        Joel David Moore
# 1            Gore Verbinski           Johnny Depp           Orlando Bloom
# 2                Sam Mendes       Christoph Waltz            Rory Kinnear
# 3         Christopher Nolan             Tom Hardy          Christian Bale
# 4               Doug Walker           Doug Walker              Rob Walker
# ...                     ...                   ...                     ...
# 5359            Jim Strouse      Jessica Williams            Chris O'Dowd
# 5360            Farhad Mann         Adelaide Kane  Benjamin Hollingsworth
# 5361       Hannaleena Hauru        Inka Haapamäki           Rosa Honkonen
# 5362  Jonathan A. Rosenbaum  Lou Diamond Phillips           Wallace Shawn
# 5363           Ravi Udyawar        Sridevi Kapoor               Sajal Ali
#
#               actor_3_name                           genres  \
# ...

# %%
final_df = old_df.append(my_df,ignore_index=True)
final_df
# Out:
#           director_name           actor_1_name      actor_2_name  \
# 0         James Cameron            CCH Pounder  Joel David Moore
# 1        Gore Verbinski            Johnny Depp     Orlando Bloom
# 2            Sam Mendes        Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan              Tom Hardy    Christian Bale
# 4           Doug Walker            Doug Walker        Rob Walker
# ...                 ...                    ...               ...
# 6139   Robert Rodriguez  Priyanka Chopra Jonas      Pedro Pascal
# 6140    Paul Greengrass              Tom Hanks     Helena Zengel
# 6141    Emerald Fennell         Carey Mulligan        Bo Burnham
# 6142        Regina King      Kingsley Ben-Adir         Eli Goree
# 6143   Kornél Mundruczó          Vanessa Kirby      Shia LaBeouf
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# ...

# %%
final_df.isna().sum()
# Out:
# director_name     0
# actor_1_name      0
# actor_2_name      3
# actor_3_name     26
# genres            6
# movie_title       0
# comb             32
# dtype: int64

# %%
final_df = final_df.dropna(how='any')

# %%
final_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
final_df.to_csv('main_data.csv',index=False)
